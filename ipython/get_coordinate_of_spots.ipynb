# %%
import requests
http_str = 'https://maps.googleapis.com/maps/api/geocode/json?address=1600+Amphitheatre+Parkway,+Mountain+View,+CA&key=AIzaSyBaZFXXOjxMDx7uqzfKRmVpbZl2XI51QPg'
response = requests.get(http_str)
resp_json_payload = response.json()
print(resp_json_payload['results'][0]['geometry']['location'])
# Out:
# {'lat': 37.42096129999999, 'lng': -122.0836555}

# %%
import requests

http_str = 'https://maps.googleapis.com/maps/api/geocode/json?address=新竹市公道五路二段395號&key=AIzaSyBaZFXXOjxMDx7uqzfKRmVpbZl2XI51QPg'
response = requests.get(http_str)
resp_json_payload = response.json()
response
print(response)
print(resp_json_payload['results'])
# Out:
# <Response [200]>
# ...

# %%
print(resp_json_payload)
# Out:
# {'results': [{'address_components': [{'long_name': '1', 'short_name': '1', 'types': ['street_number']}, {'long_name': 'Qunyi Road', 'short_name': 'Qunyi Rd', 'types': ['route']}, {'long_name': '公義里', 'short_name': '公義里', 'types': ['administrative_area_level_4', 'political']}, {'long_name': 'Zhunan Township', 'short_name': 'Zhunan Township', 'types': ['administrative_area_level_3', 'political']}, {'long_name': 'Miaoli County', 'short_name': 'Miaoli County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'Taiwan', 'short_name': 'TW', 'types': ['country', 'political']}, {'long_name': '350', 'short_name': '350', 'types': ['postal_code']}], 'formatted_address': 'No. 1, Qunyi Rd, Zhunan Township, Miaoli County, Taiwan 350', 'geometry': {'location': {'lat': 24.7191373, 'lng': 120.9110611}, 'location_type': 'ROOFTOP', 'viewport': {'northeast': {'lat': 24.7204862802915, 'lng': 120.9124100802915}, 'southwest': {'lat': 24.7177883197085, 'lng': 120.9097121197085}}}, 'place
# ...

# %%
import pandas as pd
df = pd.read_excel("taipei_school_list.xlsx")
print(df)
# Out:
#                Name                  Address              Tel
# 0          國立臺北教大實小  [106]臺北市大安區龍淵里和平東路2段94號     (02)27356186
# 1            國立政大實小      [116]臺北市文山區指南路三段12號     (02)29393610
# 2     國立台灣戲曲學院(國小部)        [114]臺北市內湖路二段177號     (02)27962666
# 3            市立松山國小     [105]臺北市松山區八德路四段746號     (02)27672907
# 4            市立西松國小      [105]臺北市松山區東光里三民路5號     (02)27609221
# ..              ...                      ...              ...
# 260      臺北市 市立啟聰學校   [103]臺北市大同區重慶北路三段320號    (02)2592-4446
# 261  臺北市 市立臺北特殊教育學校  [111]臺北市士林區忠誠路二段207巷3號    (02)2874-9117
# 262      臺北市 市立啟明學校  [111]臺北市士林區忠誠路二段207巷1號   (02)2874-0670
# 263  臺北市 市立文山特殊教育學校    [116]臺北市文山區秀明路一段169號    (02)8661-5183
# 264          臺北市立大學        [100]臺北市中正區愛國西路1號   (02)2311-3040
#
# [265 rows x 3 columns]

# %%
list_dict =[]
for d in df['Address']:
    x = d.split("]")
    http_str = 'https://maps.googleapis.com/maps/api/geocode/json?address='+x[1]+'&key=AIzaSyBaZFXXOjxMDx7uqzfKRmVpbZl2XI51QPg'
    response = requests.get(http_str)
    resp_json_payload = response.json()
    print(resp_json_payload['results'][0]['geometry']['location'])
    list_dict = list_dict + [resp_json_payload]
# Out:
# {'lat': 25.0247436, 'lng': 121.5411483}
# {'lat': 24.9846168, 'lng': 121.5798462}
# {'lat': 25.0824703, 'lng': 121.5868403}
# {'lat': 25.0498517, 'lng': 121.5776307}
# {'lat': 25.0523018, 'lng': 121.5634876}
# {'lat': 25.0491723, 'lng': 121.5485239}
# {'lat': 25.058581, 'lng': 121.550402}
# {'lat': 25.0625273, 'lng': 121.562343}
# {'lat': 25.0591373, 'lng': 121.5515398}
# {'lat': 25.0632144, 'lng': 121.5642545}
# {'lat': 25.0566674, 'lng': 121.5627846}
# {'lat': 25.046751, 'lng': 121.5700216}
# {'lat': 25.0438378, 'lng': 121.5791866}
# {'lat': 25.0401672, 'lng': 121.5578608}
# {'lat': 25.0296292, 'lng': 121.5578055}
# {'lat': 25.0313662, 'lng': 121.5629871}
# {'lat': 25.0254012, 'lng': 121.5677892}
# {'lat': 25.0384781, 'lng': 121.5866322}
# {'lat': 25.0430088, 'lng': 121.5798853}
# {'lat': 25.0395323, 'lng': 121.5675875}
# {'lat': 25.0238933, 'lng': 121.5348427}
# {'lat': 25.019229, 'lng': 121.5507594}
# {'lat': 25.0374655, 'lng': 121.5346364}
# ...

# %%
school_loc = pd.DataFrame(list_dict)
school_loc.to_csv("school_location.csv")

# %%
for d in df['Address']:
    #x = d.split("]")
    print(d)
# Out:
# [106]臺北市大安區龍淵里和平東路2段94號
# [116]臺北市文山區指南路三段12號
# [114]臺北市內湖路二段177號
# [105]臺北市松山區八德路四段746號
# [105]臺北市松山區東光里三民路5號
# [105]臺北市松山區中正里敦化北路2號
# [105]臺北市松山區敦化北路199巷18號
# [105]臺北市松山區民權東路四段200號
# [105]臺北市松山區民生東路4段97巷7號
# [105]臺北市松山區莊敬里民權東路五段1號
# [105]臺北市松山區延壽街168號
# [110]臺北市信義區雅祥里基隆路1段83巷9號
# [110]臺北市信義區永春里松山路225巷48號
# [110]臺北市信義區光復南路271號
# [110]臺北市信義區景聯里基隆路2段99號
# [110]臺北市信義區松勤街60號
# [110]臺北市信義區松仁路226號
# [110]臺北市信義區中行里褔德街253號
# [110]臺北市信義區永春里松山路287巷5號
# [110]臺北市信義區松仁路22鄰95巷20號
# [106]臺北市大安區龍門里新生南路3段33號
# [106]臺北市大安區芳和里臥龍街129號
# [106]臺北市大安區民炤里仁愛路3段22號
# [106]臺北市大安區龍雲里大安路2段99號
# [106]臺北市大安區敦安里安和路1段60號
# [106]臺北市大安區永康里愛國東路79巷11號
# [106]臺北市大安區古風里羅斯福路3段201號
# [106]臺北市大安區農場里羅斯褔路四段21號
# [106]臺北市大安區基隆路4段41巷68弄2號
# [106]臺北市大安區新生南路二段36號
# [106]臺北市大安區敦南街76巷28號
# [104]臺北市中山區恆安里民權東路1段69號
# [104]臺北市中山區力行里龍江路62號
# [104]臺北市中山區興亞里吉林路15號
# [104]臺北市中山區中央里長春路165號
# [104]臺北市中山區大直里大直街2號
# [104]臺北市中山區大佳里6鄰濱江街107號
# [104]臺北市中山區下埤里五常街16號
# [104]臺北市中山區中原里長春路116號
# [104]臺北市中山區埤頭里安東街16巷2號
# [104]臺北市中山區明水路397巷19弄1號
# ...

# %%
cdvdf = pd.read_csv("school_location.csv")

# %%
cdvdf['results'][0]
# Out:
# "[{'address_components': [{'long_name': '94', 'short_name': '94', 'types': ['street_number']}, {'long_name': 'Section 2, Heping East Road', 'short_name': 'Section 2, Heping E Rd', 'types': ['route']}, {'long_name': '龍淵里', 'short_name': '龍淵里', 'types': ['administrative_area_level_4', 'political']}, {'long_name': 'Da’an District', 'short_name': 'Da’an District', 'types': ['administrative_area_level_3', 'political']}, {'long_name': 'Taipei City', 'short_name': 'Taipei City', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'Taiwan', 'short_name': 'TW', 'types': ['country', 'political']}, {'long_name': '106', 'short_name': '106', 'types': ['postal_code']}], 'formatted_address': 'No. 94, Section 2, Heping E Rd, Da’an District, Taipei City, Taiwan 106', 'geometry': {'bounds': {'northeast': {'lat': 25.0249012, 'lng': 121.5412146}, 'southwest': {'lat': 25.0246752, 'lng': 121.5404544}}, 'location': {'lat': 25.0247436, 'lng': 121.5411483}, 'location_type': 'ROOFTOP', 'view
# ...

# %%
import plotly.express as px
import plotly.graph_objects as go
import pandas as pd
mapbox_access_token = "pk.eyJ1IjoibW9ycGhldXMyNyIsImEiOiJja2Zrd3J0dWMwb2pxMnlwY3g0Zmtza3ZuIn0.obFXuRnZeFgcHdzxq-Co4g"
